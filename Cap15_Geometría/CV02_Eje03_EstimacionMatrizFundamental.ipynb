# %% [markdown]
# <font color='red'>No se aceptan soluciones que usen metodologías distintas a las vistas en clases.</font>
#
# <font color='orange'>Está permitido usar los códigos de los ejemplos vistos en clases.</font>

# %% [markdown]
# # 1) Ingrese su Nombre y Número de alumno/a
#
# (1 Punto)

# %%
Nombre = 'Juan Perez'
ID     = '12345678K'

print('IMPORTANTE: Cambie el nombre del archivo (arriba-izquierda) por '+ID+'.ipynb')
# Out:
# IMPORTANTE: Cambie el nombre del archivo (arriba-izquierda) por 12345678K.ipynb

# %% [markdown]
# # 2) Importe las Librerías
#
# (1 Punto)
#
# *Todas las librerías de este código deben ir en esta celda. Sólo está permitido usar las librerías de los ejemplos vistos en clase.*

# %% [markdown]
# # 3) Carga de imágenes y puntos correspondientes
#
# (2 puntos)

# %% [markdown]
# ![Screen Shot 2021-09-13 at 11.05.25 am.png](data:image/png;base64,...)

# %% [markdown]
# Para la estimación de la matriz Fundamental se cuenta con dos imágenes un set de 9 puntos correspondientes encontrados manualmente.
#
# Imágenes:
#
# * `https://www.dropbox.com/s/9ixm8trsxh82hbh/Pick_01.png`
#
# * `https://www.dropbox.com/s/pas526gehevwvnh/Pick_02.png`
#
# Puntos (coordenadas (x,y) de puntos en cada imagen)
#
#
# * `https://www.dropbox.com/s/a0j6eyxow0apsgb/Pick_01_points.npy`
#
# * `https://www.dropbox.com/s/ob14kspjkavimhw/Pick_02_points.npy`
#
#
# En esta pregunta se debe:
#
# 1) Cargue las imágenes y los puntos
#
# 2) Desplegar cada imagen con sus 9 puntos

# %% [markdown]
# # 4) Estimación de la matriz fundamental (para imágenes no calibradas)
#
# (8 Puntos)
#
# Con los nueve puntos correspondientes estimar la matriz fundamental usando los métodos vistos en clases.
#
# La salida debe ser una matriz de 3 x 3 elementos.

# %% [markdown]
# # 5) Verificación de la matriz Fundamental
#
# (1 punto)
#
# Idealmente, se save que
#
#
# ${\bf m}_2^{\sf T} {\bf F}{\bf m}_1 = 0$
#
#
# donde ${\bf m}_1 = [x_1, y_1, 1]^{\sf T}$ y ${\bf m}_2 = [x_2, y_2, 1]^{\sf T}$ son dos puntos correspondientes en este par de imágenes.
#
# Escoja uno de los nueve pares de puntos correspondientes y verifique que  ${\bf m}_2^{\sf T} {\bf F}{\bf m}_1$ sea un número bajo.

# %%
# Out:
# -0.002453756295025755

# %% [markdown]
# # 6) Gráfica de la línea epipolar
#
# (3 puntos)
#
# Escoja uno de los nueve pares de puntos correspondientes y verifique que la línea epipolar del primer punto (de la primera imagen) pase aproximadamente por el segundo punto (de la segudna imagen).
